# %% [markdown]
# # Black Scholes Model

# %% [markdown]
# The Black-Scholes model was published in 1973 for pricing options on non-dividend-paying stocks. Since then, it has revolutionized quantitative finance and laid the foundation for modern derivatives pricing. The Black-Scholes model is based on a number of assumptions about how financial markets operate, including:
#
# Arbitrage-free markets
#
# Frictionless and continuous trading
#
# A constant risk-free interest rate
#
# Log-normally distributed asset price movements
#
# Constant volatility
#
# While these assumptions may not hold true in reality, they are not necessarily restrictive. The generalized Black-Scholes framework has been extended to price derivatives on other asset classes, such as the Black-76 model for commodity futures and the Garman-Kohlhagen model for foreign exchange (FX) options. These models remain widely used in derivative pricing and risk management today.
#
# **Black Scholes Formula**
#
# The Black–Scholes equation describes the price of the option over time as
#
# $$
# \frac{\partial V}{\partial t}
# + \frac 1{2}{\sigma^2 S^2} \frac{\partial^2 V}{\partial S^2}
# + r S \frac{\partial V}{\partial S} - rV = 0
# $$
#
# <br>Solving the above equation, we know that the value of a call option for a non-dividend paying stock is:<br>
#
# $$ C = SN(d_1) - Ke^{-rt}N(d_2) $$
#
# and, the corresponding put option price is:
#
# $$ P = Ke^{-rt}N(-d_2) - SN(-d_1)$$
#
# where,
#
# $$ d_1= \frac{1}{\sigma \sqrt{t}}\left[\ln{\left(\frac{S}{K}\right)} +{\left(r + \frac{\sigma^2}{2}\right)}t\right] $$
# <br>
#
# $$ d_2= d_1 - \sigma \sqrt{t} $$
# <br>
#
# $$ N(x)=\frac{1}{\sqrt{2\pi}} \int_{-\infty}^{x} \mathrm e^{-\frac{1}{2}x^2} dx $$
#
#
# $S$ is the spot price of the underlying asset<br>
# $K$ is the strike price<br>
# $r$ is the annualized continuous compounded risk free rate<br>
# $\sigma$ is the volatility of returns of the underlying asset<br>
# $t$ is time to maturity (expressed in years)<br>
# $N(x)$ is the standard normal cumulative distribution<br>
#
#
# **Greeks**
#
# | **Description** |  | **Greeks for Call Option** | **Greeks for Put Option**
# |:-----------|:----------------|:----------------|:--------
# | **Delta**  |$ \space\space \frac {\partial V}{\partial S}$ Sensitivity of Value to changes in price | $N(d_1)$ | $-N(-d_1)$
# | **Gamma**  |$ \space\space \frac {\partial ^{2}V}{\partial S^{2}}$ Sensitivity of Delta to changes in price | $\frac{N'(d_1)}{S\sigma\sqrt{t}}$
# | **Vega**   |$ \space\space \frac {\partial V}{\partial \sigma}$ Sensitivity of Value to changes in volatility | $SN'(d_1)\sqrt{t}$
# | **Theta**  |$ \space\space \frac {\partial V}{\partial t}$ Sensitivity of Value to changes in time | $-\frac{SN'(d_1)\sigma}{2\sqrt{t}}-rKe^{-rt}N(d_2)$ | $-\frac{SN'(d_1)\sigma}{2\sqrt{t}}+rKe^{-rt}N(-d_2)$
# | **Rho**    |$ \space\space \frac {\partial V}{\partial r}$  Sensitivity of Value to changes in risk-free | $Kte^{-rt}N(d_2)$ | $-Kte^{-rt}N(-d_2)$

# %% [markdown]
# **Note:** Certain third-party Python libraries (e.g., yfinance, quantmod) rely on external data sources that may be blocked or inaccessible in China. Those based in China are advised to consult their local tutor or replace these modules with locally permitted alternatives.

# %% [markdown]
# **Install Packages**

# %%
# !pip install quantmod opstrat
# Out:
# Requirement already satisfied: quantmod in ./.venv/lib/python3.14/site-packages (0.1.3)
# Collecting opstrat
#   Downloading opstrat-0.1.7-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: joblib in ./.venv/lib/python3.14/site-packages (from quantmod) (1.5.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.14/site-packages (from quantmod) (3.10.8)
# Requirement already satisfied: nbformat>=5.10.4 in ./.venv/lib/python3.14/site-packages (from quantmod) (5.10.4)
# Requirement already satisfied: numpy>=2.0.2 in ./.venv/lib/python3.14/site-packages (from quantmod) (2.4.2)
# Requirement already satisfied: pandas>=2.2.2 in ./.venv/lib/python3.14/site-packages (from quantmod) (3.0.1)
# Requirement already satisfied: plotly>=6.1.2 in ./.venv/lib/python3.14/site-packages (from quantmod) (6.6.0)
# Requirement already satisfied: pydantic>=2.8.2 in ./.venv/lib/python3.14/site-packages (from quantmod) (2.12.5)
# Requirement already satisfied: scipy>=1.13.1 in ./.venv/lib/python3.14/site-packages (from quantmod) (1.17.1)
# Requirement already satisfied: sqlalchemy>=2.0.38 in ./.venv/lib/python3.14/site-packages (from quantmod) (2.0.48)
# Requirement already satisfied: supabase>=2.27.2 in ./.venv/lib/python3.14/site-packages (from quantmod) (2.28.0)
# Requirement already satisfied: tabulate>=0.9.0 in ./.venv/lib/python3.14/site-packages (from quantmod) (0.10.0)
# Requirement already satisfied: urllib3==1.26.15 in ./.venv/lib/python3.14/site-packages (from quantmod) (1.26.15)
# Requirement already satisfied: yfinance>=1.0 in ./.venv/lib/python3.14/site-packages (from quantmod) (1.2.0)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.14/site-packages (from opstrat) (0.13.2)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.14/site-packages (from nbformat>=5.10.4->quantmod) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.14/site-packages (from nbformat>=5.10.4->quantmod) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.14/site-packages (from nbformat>=5.10.4->quantmod) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in ./.venv/lib/python3.14/site-packages (from nbformat>=5.10.4->quantmod) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.10.4->quantmod) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.10.4->quantmod) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.10.4->quantmod) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat>=5.10.4->quantmod) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.10.4->quantmod) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.14/site-packages (from pandas>=2.2.2->quantmod) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.14/site-packages (from plotly>=6.1.2->quantmod) (2.17.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.14/site-packages (from plotly>=6.1.2->quantmod) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic>=2.8.2->quantmod) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic>=2.8.2->quantmod) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./.venv/lib/python3.14/site-packages (from pydantic>=2.8.2->quantmod) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic>=2.8.2->quantmod) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.2->quantmod) (1.17.0)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.14/site-packages (from sqlalchemy>=2.0.38->quantmod) (3.3.2)
# Requirement already satisfied: realtime==2.28.0 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (2.28.0)
# Requirement already satisfied: supabase-functions==2.28.0 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (2.28.0)
# Requirement already satisfied: storage3==2.28.0 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (2.28.0)
# Requirement already satisfied: supabase-auth==2.28.0 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (2.28.0)
# Requirement already satisfied: postgrest==2.28.0 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (2.28.0)
# Requirement already satisfied: httpx<0.29,>=0.26 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (0.28.1)
# Requirement already satisfied: yarl>=1.22.0 in ./.venv/lib/python3.14/site-packages (from supabase>=2.27.2->quantmod) (1.23.0)
# Requirement already satisfied: deprecation>=2.1.0 in ./.venv/lib/python3.14/site-packages (from postgrest==2.28.0->supabase>=2.27.2->quantmod) (2.1.0)
# Requirement already satisfied: websockets<16,>=11 in ./.venv/lib/python3.14/site-packages (from realtime==2.28.0->supabase>=2.27.2->quantmod) (15.0.1)
# Requirement already satisfied: pyiceberg>=0.10.0 in ./.venv/lib/python3.14/site-packages (from storage3==2.28.0->supabase>=2.27.2->quantmod) (0.11.1)
# Requirement already satisfied: pyjwt>=2.10.1 in ./.venv/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase>=2.27.2->quantmod) (2.11.0)
# Requirement already satisfied: strenum>=0.4.15 in ./.venv/lib/python3.14/site-packages (from supabase-functions==2.28.0->supabase>=2.27.2->quantmod) (0.4.15)
# Requirement already satisfied: anyio in ./.venv/lib/python3.14/site-packages (from httpx<0.29,>=0.26->supabase>=2.27.2->quantmod) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx<0.29,>=0.26->supabase>=2.27.2->quantmod) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx<0.29,>=0.26->supabase>=2.27.2->quantmod) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.14/site-packages (from httpx<0.29,>=0.26->supabase>=2.27.2->quantmod) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase>=2.27.2->quantmod) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in ./.venv/lib/python3.14/site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase>=2.27.2->quantmod) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in ./.venv/lib/python3.14/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase>=2.27.2->quantmod) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in ./.venv/lib/python3.14/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase>=2.27.2->quantmod) (4.1.0)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (2.32.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (8.3.1)
# Requirement already satisfied: rich<15.0.0,>=10.11.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (14.3.3)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (1.7.3)
# Requirement already satisfied: fsspec>=2023.1.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (2026.2.0)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (3.3.2)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (9.1.4)
# Requirement already satisfied: pyroaring<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (1.0.3)
# Requirement already satisfied: cachetools<7.0,>=5.5 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (6.2.6)
# Requirement already satisfied: zstandard<1.0.0,>=0.13.0 in ./.venv/lib/python3.14/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.14/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.14/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase>=2.27.2->quantmod) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in ./.venv/lib/python3.14/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase>=2.27.2->quantmod) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.14/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase>=2.27.2->quantmod) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase>=2.27.2->quantmod) (3.0)
# Requirement already satisfied: multidict>=4.0 in ./.venv/lib/python3.14/site-packages (from yarl>=1.22.0->supabase>=2.27.2->quantmod) (6.7.1)
# Requirement already satisfied: propcache>=0.2.1 in ./.venv/lib/python3.14/site-packages (from yarl>=1.22.0->supabase>=2.27.2->quantmod) (0.4.1)
# Requirement already satisfied: multitasking>=0.0.7 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (0.0.12)
# Requirement already satisfied: pytz>=2022.5 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (4.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in ./.venv/lib/python3.14/site-packages (from yfinance>=1.0->quantmod) (7.34.0)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.14/site-packages (from beautifulsoup4>=4.11.1->yfinance>=1.0->quantmod) (2.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib->quantmod) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib->quantmod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.14/site-packages (from matplotlib->quantmod) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib->quantmod) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.14/site-packages (from matplotlib->quantmod) (12.1.1)
# Downloading opstrat-0.1.7-py3-none-any.whl (11 kB)
# Installing collected packages: opstrat
# Successfully installed opstrat-0.1.7

# %% [markdown]
# **Import Libraries**

# %%
# Import libraries
import pandas as pd
import numpy as np
from scipy.stats import norm
from tabulate import tabulate

# %% [markdown]
# ## Section 1: Calculate Option Price

# %%
help(black_scholes_price)
# Out:
# Help on function black_scholes_price in module __main__:
#
# black_scholes_price(S, K, T, r, sigma, option_type='call')
#     Black Scholes Option Pricing

# %%
# Define function for pricing
def black_scholes_price(S, K, T, r, sigma, option_type='call'):
    '''Black Scholes Option Pricing
    S - Spot 
    K- Strike
    T - Time to maturity (years)
    r - Risk-free Rate
    sigma - Volatility (annualized)
    option_type - 'call' or 'put'
    '''

    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)

    if option_type == 'call':
        return S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    elif option_type == 'put':
        return K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)
    else:
        raise ValueError("option_type must be 'call' or 'put'")

# %%
# BS Price
black_scholes_price(100,100,1,0.05,0.2,option_type='call')
# Out:
# np.float64(10.450583572185565)

# %%
# BS Price
black_scholes_price(100,100,1,0.05,0.2,option_type='put')
# Out:
# np.float64(5.573526022256971)

# %% [markdown]
# ## Section 2: Calculate Greeks

# %%
def compute_greeks(S, K, T, r, sigma, option_type='call'):
    '''Compute option greeks'''

    d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)

    delta = norm.cdf(d1) if option_type == 'call' else -norm.cdf(-d1)
    gamma = norm.pdf(d1) / (S * sigma * np.sqrt(T))
    vega = S * norm.pdf(d1) * np.sqrt(T) / 100

    theta_call = (-S * norm.pdf(d1) * sigma / (2 * np.sqrt(T)) - r * K * np.exp(-r * T) * norm.cdf(d2)) / 365
    theta_put = (-S * norm.pdf(d1) * sigma / (2 * np.sqrt(T)) + r * K * np.exp(-r * T) * norm.cdf(-d2)) / 365

    rho_call = K * T * np.exp(-r * T) * norm.cdf(d2) / 100
    rho_put = -K * T * np.exp(-r * T) * norm.cdf(-d2) / 100

    theta = theta_call if option_type == 'call' else theta_put
    rho = rho_call if option_type == 'call' else rho_put

    return {'Delta': delta, 'Gamma': gamma, 'Vega': vega, 'Theta': theta, 'Rho': rho}

# %%
# Compute Greeks
compute_greeks(100,100,1,0.05,0.2,option_type='call')

# %% [markdown]
# ## Section 3: Quantmod Option Module
#
# The quantmod option module offers a versatile and comprehensive toolkit for valuing a wide range of financial derivatives. It includes multiple pricing models implemented in Python such as Black-Scholes, Binomial, and Monte Carlo methods, enabling accurate computation of theoretical prices for European, American, and exotic options, including Asian and barrier options.
#
# Built with a clean, object-oriented architecture and leveraging Pydantic for smart function calling and input validation, the module allows users to easily specify input parameters, configure model-specific settings like time steps or simulation paths, handle early exercise features, and generate precise valuations all through a unified and intuitive Python API.
#
# Its flexible design makes it ideal for creating intelligent option agents and building custom MCP servers by harnessing the power of function calling.
#
# Key Features:
#
# * OptionInputs: A structured class to standardize and validate input parameters.
#
# * BlackScholesOptionPricing: Implements the Black-Scholes model for pricing options and calculating Greeks.
#
# * BinomialOptionPricing: Prices options using the binomial tree method, including support for early exercise.
#
# * MonteCarloOptionPricing: Uses Monte Carlo simulation to price European, Asian, and barrier options.

# %% [markdown]
# Let's now price the option Black Scholes Options using quantmod

# %%
# Import Quantmod Option Module
from quantmod.models import OptionInputs, BlackScholesOptionPricing

# %%
# Define option inputs parameters
inputs=OptionInputs(
    spot=100,
    strike=100,
    ttm=1,
    rate=0.05,
    volatility=0.2
    )

# Initialize the BS Option Pricing Engine
option = BlackScholesOptionPricing(inputs=inputs)

# %%
# Print the BS option price
header = ['Type', 'Option Price', 'Delta', 'Gamma', 'Theta', 'Vega', 'Rho']
table = [
    ['Call', option.call_price, option.call_delta, option.gamma, option.call_theta, option.vega, option.call_rho],
    ['Put', option.put_price, option.put_delta, option.gamma, option.put_theta, option.vega, option.put_rho]
]

print(tabulate(table,header))

# %% [markdown]
# ## Section 4: Visualise Multi-leg Payoff

# %%
# Import opstrat
import opstrat as op

# %% [markdown]
# **Single Payoff: Call Option**

# %%
# Plot option payoff
op.single_plotter(
    op_type='c',
    spot=inputs.spot,
    spot_range=25,
    strike=inputs.strike,
    tr_type='s',
    op_pr=option.call_price
)

# %% [markdown]
# **Multi-leg Payoff: Straddle**

# %%
# Straddle
op_1 = {'op_type': 'c', 'strike':inputs.strike, 'tr_type': 's', 'op_pr': option.call_price}
op_2 = {'op_type': 'p', 'strike':inputs.strike, 'tr_type': 's', 'op_pr': option.put_price}

# plot
op_list = [op_1, op_2]
op.multi_plotter(spot=inputs.spot, spot_range=25, op_list=op_list)

# %% [markdown]
# **Multi-leg Payoff: Strangle**

# %%
# Strangle
leg1_inputs =  OptionInputs(spot=100,strike=110,ttm=1,rate=0.05,volatility=0.2)
leg1 = BlackScholesOptionPricing(leg1_inputs)

leg2_inputs =  OptionInputs(spot=100,strike=90,ttm=1,rate=0.05,volatility=0.2)
leg2 = BlackScholesOptionPricing(leg2_inputs)

op_1 = {'op_type': 'c', 'strike':leg1_inputs.strike, 'tr_type': 's', 'op_pr': leg1.call_price}
op_2 = {'op_type': 'p', 'strike':leg2_inputs.strike, 'tr_type': 's', 'op_pr': leg2.put_price}

# plot
op_list = [op_1, op_2]
op.multi_plotter(spot=inputs.spot, spot_range=25, op_list=op_list)

# %% [markdown]
# **Multi-leg Payoff: Ironfly**

# %%
# Ironfly
leg2_inputs =  OptionInputs(spot=100,strike=90,ttm=1,rate=0.05,volatility=0.2)
leg2 = BlackScholesOptionPricing(leg2_inputs)

leg3_inputs =  OptionInputs(spot=100,strike=110,ttm=1,rate=0.05,volatility=0.2)
leg3 = BlackScholesOptionPricing(leg3_inputs)

op_1 = {'op_type': 'c', 'strike':inputs.strike, 'tr_type': 's', 'op_pr': option.call_price}
op_2 = {'op_type': 'p', 'strike':inputs.strike, 'tr_type': 's', 'op_pr': option.put_price}
op_3 = {'op_type': 'p', 'strike':leg2_inputs.strike, 'tr_type': 'b', 'op_pr': leg2.put_price}
op_4 = {'op_type': 'c', 'strike':leg3_inputs.strike, 'tr_type': 'b', 'op_pr': leg3.call_price}

op_list = [op_1, op_2, op_3, op_4]
op.multi_plotter(spot=inputs.spot, spot_range=25, op_list=op_list)

# %% [markdown]
# ## Section 5: Greeks Analysis
#
# We'll now retrieve option chain for SPY for March 2026 expiration from yahoo finance and manipulate the option chain to perform our analysis.
#
# https://finance.yahoo.com/quote/SPY260320C00680000/

# %%
# Import quantmod
from quantmod.markets import getTicker
import quantmod.charts
from datetime import datetime

# %%
# Get SPY option chain
spy = getTicker('SPY')
options = spy.option_chain('2026-03-20')
dte = (datetime(2026, 3, 20) - datetime.today()).days/365

# %%
# August 2025 620 SPY call option price
spy_opt = BlackScholesOptionPricing(OptionInputs(spot=643,strike=680,ttm=dte,rate=0.0,volatility=0.1328))

print(f'Option Price of SPY260320C00680000 with BS Model is {spy_opt.call_price:0.4f}')

# %%
# Filter calls for strike at or above 650 and puts at or below 700
df = options.calls[(options.calls['strike'] >= 650) & (options.calls['strike'] <= 700)].copy()
df = df[['strike', 'lastPrice']]
# df.reset_index(drop=True, inplace=True)

# Add implied volatility and initialize Greeks
df['IV'] = 0.20
df['Delta'] = 0.0
df['Gamma'] = 0.0
df['Vega'] = 0.0
df['Theta'] = 0.0

for idx, row in df.iterrows():
    opt = BlackScholesOptionPricing(
        OptionInputs(
            spot=643,
            strike=row['strike'],
            ttm=dte,
            rate=0.0,
            volatility=row['IV']
        )
    )

    df.at[idx, 'Delta'] = opt.call_delta
    df.at[idx, 'Gamma'] = opt.gamma
    df.at[idx, 'Vega'] = opt.vega
    df.at[idx, 'Theta'] = opt.call_theta

# Set index
df.set_index('strike', inplace=True)
df

# %% [markdown]
# **Visualise Greeks Vs Strike Behaviour**

# %%
# Subplots of greeks
df[['Delta', 'Gamma', 'Vega', 'Theta']].iplot(kind="subplots", title="Greeks Vs Strikes", showlegend=True)

# %% [markdown]
# ## Section 6: Also Read
#
# 📌 [Opstrat](https://github.com/hashabcd/opstrat/)
#
# 📌 [Quantmod Option Pricing](https://kannansingaravelu.com/quantmod/models/)
#
#
# ---
# [Kannan Singaravelu](https://www.linkedin.com/in/kannansi)
